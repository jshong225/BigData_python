# %%
import pandas as pd

# %%
#pd.read_excel()
s1 = pd.read_csv('./03. 대구도시철도공사_일별시간별승하차인원_20171231.csv', 
            encoding="cp949")

# %%
s2 = pd.read_csv('./04. 대구도시철도공사_일별시간별승하차인원_20181231.csv', 
            encoding="cp949")

# %%
s3 = pd.read_csv('./05. 대구도시철도공사_일별시간별승하차인원_20190831.csv', 
            encoding="cp949", skiprows=2)

# %%
s1.head(1)
# Out:
#    월  일   역번호    역명  승하  05~06  06~07  07~08  08~09  09~10  ...  15~16  16~17  \
# 0  1  1  1150  설화명곡  승차     22     37     61    111    167  ...    270    216
#
#    17~18  18~19  19~20  20~21  21~22  22~23  23~24    일계
# 0    192    138    125     87     56     47      7  2867
#
# [1 rows x 25 columns]

# %%
s2.head(1)
# Out:
#    월  일   역번호    역명 승하차  05~06  06~07  07~08  08~09  09~10  ...  15~16  16~17  \
# 0  1  1  1150  설화명곡  승차     45     46     74    110    145  ...    267    207
#
#    17~18  18~19  19~20  20~21  21~22  22~23  23~24    일계
# 0    211    166    108     73     50     40      6  2787
#
# [1 rows x 25 columns]

# %%
s3.head(1)
# Out:
#    월  일   역번호    역명  승하  05~06  06~07  07~08  08~09  09~10  ...  15~16  16~17  \
# 0  1  1  1150  설화명곡  승차     48     59     65     99    139  ...    228    204
#
#    17~18  18~19  19~20  20~21  21~22  22~23  23~24    일계
# 0    202    150     95     62     53     30      4  2545
#
# [1 rows x 25 columns]

# %%
s2.columns
# Out:
# Index(['월', '일', '역번호', '역명', '승하차', '05~06', '06~07', '07~08', '08~09',
#        '09~10', '10~11', '11~12', '12~13', '13~14', '14~15', '15~16', '16~17',
#        '17~18', '18~19', '19~20', '20~21', '21~22', '22~23', '23~24', '일계'],
#       dtype='object')

# %%
colname = ['월', '일', '역번호', '역명', '승하차', '05~06', '06~07', '07~08', '08~09',
       '09~10', '10~11', '11~12', '12~13', '13~14', '14~15', '15~16', '16~17',
       '17~18', '18~19', '19~20', '20~21', '21~22', '22~23', '23~24', '일계']

# %%
s1.columns = colname
s3.columns = colname

# %%
s1.head(1)
# Out:
#    월  일   역번호    역명 승하차  05~06  06~07  07~08  08~09  09~10  ...  15~16  16~17  \
# 0  1  1  1150  설화명곡  승차     22     37     61    111    167  ...    270    216
#
#    17~18  18~19  19~20  20~21  21~22  22~23  23~24    일계
# 0    192    138    125     87     56     47      7  2867
#
# [1 rows x 25 columns]

# %%
s1['년도'] = 2017 # [~~~~]
s2['년도'] = 2018
s3['년도'] = 2019

# %%
s1['역명'].unique(), len(s1['역명'].unique())
# Out:
# (array(['설화명곡', '화원', '대곡', '진천', '월배', '상인', '월촌', '송현', '성당못', '대명',
#         '안지랑', '현충로', '영대병원', '교대', '명덕1', '반월당1', '중앙로', '대구역', '칠성시장',
#         '신천', '동대구역', '동구청', '아양교', '동촌', '해안', '방촌', '용계', '율하', '신기',
#         '반야월', '각산', '안심', '문양', '다사', '대실', '강창', '계명대', '성서산업단지', '이곡',
#         '용산', '죽전', '감삼', '두류', '내당', '반고개', '신남2', '반월당2', '경대병원', '대구은행',
#         '범어', '수성구청', '만촌', '담티', '연호', '대공원', '고산', '신매', '사월', '정평',
#         '임당', '영남대', '칠곡경대병원', '학정', '팔거', '동천', '칠곡운암', '구암', '태전', '매천',
#         '매천시장', '팔달', '공단', '만평', '팔달시장', '원대', '북구청', '달성공원', '서문시장',
#         '신남3', '남산', '명덕3', '건들바위', '대봉교', '수성시장', '수성구민운동장', '어린이회관',
#         '황금', '수성못', '지산', '범물', '용지'], dtype=object), 91)

# %%
s1.shape, s2.shape, s3.shape   ##결측치 확인 하는법
# Out:
# ((66430, 26), (66430, 26), (44226, 26))

# %%
subway = pd.concat( [s1,s2,s3] )

# %%
subway.shape
# Out:
# (177086, 26)

# %%
subway.to_csv('./대구지하철 201701~201908.csv', index=False, encoding="cp949")

# %%
subway.head(1)
# Out:
#    월  일   역번호    역명 승하차  05~06  06~07  07~08  08~09  09~10  ...  16~17  17~18  \
# 0  1  1  1150  설화명곡  승차     22     37     61    111    167  ...    216    192
#
#    18~19  19~20  20~21  21~22  22~23  23~24    일계    년도
# 0    138    125     87     56     47      7  2867  2017
#
# [1 rows x 26 columns]

# %%
subway.tail(1) ##인덱스가 초기화되지 않음
# Out:
#        월   일   역번호  역명 승하차  05~06  06~07  07~08  08~09  09~10  ...  16~17  \
# 44225  8  31  3410  용지  하차      6     62     66    132    128  ...    158
#
#        17~18  18~19  19~20  20~21  21~22  22~23  23~24    일계    년도
# 44225    165    178    119     92     90     68     74  2246  2019
#
# [1 rows x 26 columns]

# %%
subway = subway.reset_index()

# %%
subway.tail(1) ## 인덱스가 초기화되었음
# Out:
#         index  월   일   역번호  역명 승하차  05~06  06~07  07~08  08~09  ...  16~17  \
# 177085  44225  8  31  3410  용지  하차      6     62     66    132  ...    158
#
#         17~18  18~19  19~20  20~21  21~22  22~23  23~24    일계    년도
# 177085    165    178    119     92     90     68     74  2246  2019
#
# [1 rows x 27 columns]

# %%
subway.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 177086 entries, 0 to 177085
# Data columns (total 27 columns):
# index    177086 non-null int64
# 월        177086 non-null int64
# 일        177086 non-null int64
# 역번호      177086 non-null int64
# 역명       177086 non-null object
# 승하차      177086 non-null object
# 05~06    177086 non-null int64
# 06~07    177086 non-null int64
# 07~08    177086 non-null int64
# 08~09    177086 non-null int64
# 09~10    177086 non-null int64
# 10~11    177086 non-null int64
# 11~12    177086 non-null int64
# 12~13    177086 non-null int64
# 13~14    177086 non-null int64
# 14~15    177086 non-null int64
# 15~16    177086 non-null int64
# 16~17    177086 non-null int64
# 17~18    177086 non-null int64
# 18~19    177086 non-null int64
# 19~20    177086 non-null int64
# 20~21    177086 non-null int64
# 21~22    177086 non-null int64
# 22~23    177086 non-null int64
# 23~24    177086 non-null int64
# 일계       177086 non-null int64
# 년도       177086 non-null int64
# dtypes: int64(25), object(2)
# memory usage: 36.5+ MB

# %%
subway['역번호'].dtype
# Out:
# dtype('int64')

# %%
subway['역번호'] = subway['역번호'].astype('str')

# %%
subway['역번호'].dtype
# Out:
# dtype('O')

# %%
subway.isnull().sum()
# Out:
# index    0
# 월        0
# 일        0
# 역번호      0
# 역명       0
# 승하차      0
# 05~06    0
# 06~07    0
# 07~08    0
# 08~09    0
# 09~10    0
# 10~11    0
# 11~12    0
# 12~13    0
# 13~14    0
# 14~15    0
# 15~16    0
# 16~17    0
# 17~18    0
# 18~19    0
# 19~20    0
# 20~21    0
# 21~22    0
# 22~23    0
# 23~24    0
# 일계       0
# 년도       0
# dtype: int64

# %%
subway.isnull().sum().sum()
# Out:
# 0

# %%
subway['역번호'].unique(), len(subway['역번호'].unique())
# Out:
# (array(['1150', '1160', '1170', '1180', '1190', '1200', '1210', '1220',
#         '1230', '1240', '1250', '1260', '1270', '1280', '1290', '1300',
#         '1310', '1320', '1330', '1340', '1350', '1360', '1370', '1380',
#         '1390', '1400', '1410', '1420', '1430', '1440', '1450', '1460',
#         '2160', '2170', '2180', '2190', '2200', '2210', '2220', '2230',
#         '2240', '2250', '2260', '2270', '2280', '2290', '2300', '2310',
#         '2320', '2330', '2340', '2350', '2360', '2370', '2380', '2390',
#         '2400', '2410', '2420', '2430', '2440', '3120', '3130', '3140',
#         '3150', '3160', '3170', '3180', '3190', '3200', '3210', '3220',
#         '3230', '3240', '3250', '3260', '3270', '3280', '3290', '3300',
#         '3310', '3320', '3330', '3340', '3350', '3360', '3370', '3380',
#         '3390', '3400', '3410'], dtype=object), 91)

# %%
subway.columns
# Out:
# Index(['index', '월', '일', '역번호', '역명', '승하차', '05~06', '06~07', '07~08',
#        '08~09', '09~10', '10~11', '11~12', '12~13', '13~14', '14~15', '15~16',
#        '16~17', '17~18', '18~19', '19~20', '20~21', '21~22', '22~23', '23~24',
#        '일계', '년도'],
#       dtype='object')

# %%
t = pd.DataFrame(subway.groupby(by=['역번호', '역명',
                                    '년도', '승하차'])['일'].count())
t
# Out:
#                       일
# 역번호  역명   년도   승하차
# 1150 설화명곡 2017 승차   365
#                하차   365
#           2018 승차   365
#                하차   365
#           2019 승차   243
#                하차   243
# 1160 화원   2017 승차   365
#                하차   365
#           2018 승차   365
#                하차   365
#           2019 승차   243
#                하차   243
# 1170 대곡   2017 승차   365
#                하차   365
#           2018 승차   365
#                하차   365
#           2019 승차   243
#                하차   243
# 1180 진천   2017 승차   365
#                하차   365
#           2018 승차   365
#                하차   365
#           2019 승차   243
#                하차   243
# 1190 월배   2017 승차   365
#                하차   365
#           2018 승차   365
#                하차   365
#           2019 승차   243
#                하차   243
# ...                 ...
# 3370 황금   2017 승차   365
#                하차   365
#           2018 승차   365
#                하차   365
#           2019 승차   243
#                하차   243
# 3380 수성못  2017 승차   365
#                하차   365
#           2018 승차   365
#                하차   365
#           2019 승차   243
#                하차   243
# 3390 지산   2017 승차   365
#                하차   365
#           2018 승차   365
#                하차   365
#           2019 승차   243
#                하차   243
# 3400 범물   2017 승차   365
#                하차   365
#           2018 승차   365
#                하차   365
#           2019 승차   243
#                하차   243
# 3410 용지   2017 승차   365
#                하차   365
#           2018 승차   365
#                하차   365
#           2019 승차   243
#                하차   243
#
# [546 rows x 1 columns]

# %%
t2 = t[t['일'] < 365]  ##boolean indexing

# %%
t2 = t2.reset_index()
t2['년도'].unique()
# Out:
# array([2019], dtype=int64)

# %%
t = t.reset_index()
t[ (t['일'] < 365) & (t['년도'] != 2019) ] # &(and) | (or)
# Out:
# Empty DataFrame
# Columns: [역번호, 역명, 년도, 승하차, 일]
# Index: []

# %%
t['역번호']
# Out:
# 0      1150
# 1      1150
# 2      1150
# 3      1150
# 4      1150
# 5      1150
# 6      1160
# 7      1160
# 8      1160
# 9      1160
# 10     1160
# 11     1160
# 12     1170
# 13     1170
# 14     1170
# 15     1170
# 16     1170
# 17     1170
# 18     1180
# 19     1180
# 20     1180
# 21     1180
# 22     1180
# 23     1180
# 24     1190
# 25     1190
# 26     1190
# 27     1190
# 28     1190
# 29     1190
#        ...
# 516    3370
# 517    3370
# 518    3370
# 519    3370
# 520    3370
# 521    3370
# 522    3380
# 523    3380
# 524    3380
# 525    3380
# 526    3380
# 527    3380
# 528    3390
# 529    3390
# 530    3390
# 531    3390
# 532    3390
# 533    3390
# 534    3400
# 535    3400
# 536    3400
# 537    3400
# 538    3400
# 539    3400
# 540    3410
# 541    3410
# 542    3410
# 543    3410
# 544    3410
# 545    3410
# Name: 역번호, Length: 546, dtype: object

# %%
month = pd.DataFrame(subway.groupby(by=['년도', '월', '역명'])['일계'].mean())

# %%
month = month.reset_index()
month
# Out:
#         년도  월      역명            일계
# 0     2017  1      각산   4102.145161
# 1     2017  1      감삼   6750.822581
# 2     2017  1      강창   3408.645161
# 3     2017  1    건들바위   1198.467742
# 4     2017  1    경대병원   6116.725806
# 5     2017  1     계명대   5802.241935
# 6     2017  1      고산   2170.209677
# 7     2017  1      공단   1106.806452
# 8     2017  1      교대   3811.483871
# 9     2017  1      구암   1777.064516
# 10    2017  1      남산   2439.435484
# 11    2017  1      내당   4362.177419
# 12    2017  1      다사   2008.435484
# 13    2017  1    달성공원   1285.112903
# 14    2017  1      담티   2638.661290
# 15    2017  1      대곡   6423.693548
# 16    2017  1     대공원    407.387097
# 17    2017  1     대구역   9731.016129
# 18    2017  1    대구은행   5727.951613
# 19    2017  1      대명   4507.612903
# 20    2017  1     대봉교   3113.000000
# 21    2017  1      대실   5972.064516
# 22    2017  1     동구청   3743.951613
# 23    2017  1    동대구역  21647.451613
# 24    2017  1      동천   1764.596774
# 25    2017  1      동촌   1892.112903
# 26    2017  1      두류   8071.645161
# 27    2017  1      만촌   3766.709677
# 28    2017  1      만평   1980.161290
# 29    2017  1      매천   1916.677419
# ...    ... ..     ...           ...
# 2882  2019  8     영남대   6244.387097
# 2883  2019  8    영대병원   6101.774194
# 2884  2019  8      용계   1992.274194
# 2885  2019  8      용산   8285.854839
# 2886  2019  8      용지   2402.435484
# 2887  2019  8      원대   1557.354839
# 2888  2019  8      월배   4472.048387
# 2889  2019  8      월촌   4800.645161
# 2890  2019  8      율하   4669.532258
# 2891  2019  8      이곡   3952.919355
# 2892  2019  8      임당   3014.661290
# 2893  2019  8      정평   4172.806452
# 2894  2019  8      죽전   5394.209677
# 2895  2019  8     중앙로  20264.774194
# 2896  2019  8      지산   2345.467742
# 2897  2019  8      진천   6823.596774
# 2898  2019  8   청라언덕2   4707.112903
# 2899  2019  8   청라언덕3   1590.080645
# 2900  2019  8  칠곡경대병원   1338.661290
# 2901  2019  8    칠곡운암   3949.080645
# 2902  2019  8    칠성시장   5055.725806
# 2903  2019  8      태전   2076.322581
# 2904  2019  8      팔거   4442.129032
# 2905  2019  8      팔달   1140.258065
# 2906  2019  8    팔달시장   2573.209677
# 2907  2019  8      학정    317.290323
# 2908  2019  8      해안   2716.677419
# 2909  2019  8     현충로   3913.596774
# 2910  2019  8      화원   3943.338710
# 2911  2019  8      황금   3114.241935
#
# [2912 rows x 4 columns]

# %%
top10 = month.sort_values(by='일계', ascending=False).head(10)   # 내림차순
bottom10 = month.sort_values(by='일계').head(10)                 # 오름차순

# %%
top10  ##반월당이 시내다 라는 뜻
# Out:
#         년도   월    역명            일계
# 2585  2019   5  반월당2  27694.419355
# 128   2017   2  반월당2  27487.446429
# 401   2017   5  반월당2  26836.596774
# 2312  2019   2  반월당2  26810.857143
# 1311  2018   3  반월당2  26636.193548
# 2130  2018  12  반월당2  26612.322581
# 2403  2019   3  반월당2  26574.612903
# 2221  2019   1  반월당2  26275.306452
# 2767  2019   7  반월당2  26243.274194
# 2039  2018  11  반월당2  25990.316667

# %%
bottom10
# Out:
#         년도   월  역명          일계
# 1269  2018   2  학정  285.928571
# 86    2017   1  학정  291.322581
# 1178  2018   1  학정  291.548387
# 1815  2018   8  학정  308.822581
# 1906  2018   9  학정  313.066667
# 1724  2018   7  학정  314.500000
# 723   2017   8  학정  316.645161
# 2907  2019   8  학정  317.290323
# 905   2017  10  학정  324.274194
# 177   2017   2  학정  324.517857

# %%
year = pd.DataFrame(subway.groupby(by=['년도','역명'])['일계'].mean())

# %%
year_top10 = year.sort_values(by='일계', ascending=False).head(10)   # 내림차순
year_bottom10 = year.sort_values(by='일계').head(10)                 # 오름차순

# %%
year_top10
# Out:
#                      일계
# 년도   역명
# 2019 반월당2  26090.604938
# 2018 반월당2  25300.190411
# 2017 반월당2  25115.367123
#      중앙로   20940.647945
# 2019 중앙로   20414.876543
# 2018 중앙로   20388.798630
# 2019 동대구역  18835.958848
# 2017 동대구역  18569.212329
# 2018 동대구역  18297.342466
# 2017 상인    13269.935616

# %%
year_bottom10
# Out:
#                     일계
# 년도   역명
# 2018 학정     337.880822
# 2017 학정     343.815068
# 2019 학정     364.623457
# 2018 연호     684.508219
# 2017 연호     707.068493
# 2019 연호     725.452675
# 2017 매천시장   858.323288
# 2018 매천시장   873.316438
# 2019 매천시장  1124.300412
# 2017 팔달    1134.824658

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
year_top10 = year_top10.reset_index()
year_top10 = year_top10[['역명', '일계', '년도']]
year_top10['역명_년'] =  year_top10['년도'].astype('str') + year_top10['역명']
year_top10 = year_top10.set_index('역명_년')
year_top10
# Out:
#             역명            일계    년도
# 역명_년
# 2019반월당2  반월당2  26090.604938  2019
# 2018반월당2  반월당2  25300.190411  2018
# 2017반월당2  반월당2  25115.367123  2017
# 2017중앙로    중앙로  20940.647945  2017
# 2019중앙로    중앙로  20414.876543  2019
# 2018중앙로    중앙로  20388.798630  2018
# 2019동대구역  동대구역  18835.958848  2019
# 2017동대구역  동대구역  18569.212329  2017
# 2018동대구역  동대구역  18297.342466  2018
# 2017상인      상인  13269.935616  2017

# %%
year_top10['일계'].plot(kind='bar')
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 48152 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\user\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 50900 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\user\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 45817 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\user\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 51473 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\user\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 50521 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\user\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 47196 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\user\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 46041 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\user\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 45824 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\user\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 44396 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\user\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 50669 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\user\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 49345 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\user\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 51064 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\user\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 48152 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\user\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 50900 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\user\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 45817 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\user\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 51473 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\user\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 50521 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\user\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 47196 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\user\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 46041 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\user\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 45824 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\user\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 44396 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\user\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 50669 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\user\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 49345 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\user\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 51064 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\user\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 47749 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\user\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 45380 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\user\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 47749 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\user\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 45380 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
## 포리움 이용해보기

# %%
station = pd.read_csv('./06. 대구도시철도공사_도시철도역사정보_20190923.csv', encoding='cp949')

# %%
station.head()
# Out:
#    역번호   역사명   노선번호          노선명             영문역사명 한자역사명 환승역구분 환승노선번호 환승노선명  \
# 0  115  설화명곡  S2701  대구 도시철도 1호선  SeolhwaMyeonggok  舌化椧谷   일반역    NaN   NaN
# 1  116    화원  S2701  대구 도시철도 1호선            Hwawon    花園   일반역    NaN   NaN
# 2  117    대곡  S2701  대구 도시철도 1호선            Daegok    大谷   일반역    NaN   NaN
# 3  118    진천  S2701  대구 도시철도 1호선          Jincheon    辰泉   일반역    NaN   NaN
# 4  119    월배  S2701  대구 도시철도 1호선            Wolbae    月背   일반역    NaN   NaN
#
#          역위도         역경도           운영기관명                     역사도로명주소  \
# 0  35.798718  128.489318  대구광역시 대구도시철도공사      대구광역시 달성군 화원읍 비슬로 2476
# 1  35.804357  128.500404  대구광역시 대구도시철도공사    대구광역시 달성군 화원읍 비슬로 지하2600
# 2  35.809497  128.510391  대구광역시 대구도시철도공사  대구광역시 달서구 비슬로 지하2718 (대곡동)
# 3  35.813826  128.520397  대구광역시 대구도시철도공사    대구광역시 달서구 월배로 지하76 (진천동)
# 4  35.816276  128.528392  대구광역시 대구도시철도공사   대구광역시 달서구 월배로 지하143 (진천동)
#
#          역사전화번호     데이터기준일자
# 0  053-643-2674  2019-09-23
# 1  053-643-5125  2019-09-23
# 2  053-644-7723  2019-09-23
# 3  053-642-7723  2019-09-23
# 4  053-642-7732  2019-09-23

# %%
station['역번호'].unique(), subway['역번호'].unique()
# Out:
# (array([115, 116, 117, 118, 119, 120, 121, 122, 123, 124, 125, 126, 127,
#         128, 129, 130, 131, 132, 133, 134, 135, 136, 137, 138, 139, 140,
#         141, 142, 143, 144, 145, 146, 216, 217, 218, 219, 220, 221, 222,
#         223, 224, 225, 226, 227, 228, 229, 230, 231, 232, 233, 234, 235,
#         236, 237, 238, 239, 240, 241, 242, 243, 244, 312, 313, 314, 315,
#         316, 317, 318, 319, 320, 321, 322, 323, 324, 325, 326, 327, 328,
#         329, 330, 331, 332, 333, 334, 335, 336, 337, 338, 339, 340, 341],
#        dtype=int64),
#  array(['1150', '1160', '1170', '1180', '1190', '1200', '1210', '1220',
#         '1230', '1240', '1250', '1260', '1270', '1280', '1290', '1300',
#         '1310', '1320', '1330', '1340', '1350', '1360', '1370', '1380',
#         '1390', '1400', '1410', '1420', '1430', '1440', '1450', '1460',
#         '2160', '2170', '2180', '2190', '2200', '2210', '2220', '2230',
#         '2240', '2250', '2260', '2270', '2280', '2290', '2300', '2310',
#         '2320', '2330', '2340', '2350', '2360', '2370', '2380', '2390',
#         '2400', '2410', '2420', '2430', '2440', '3120', '3130', '3140',
#         '3150', '3160', '3170', '3180', '3190', '3200', '3210', '3220',
#         '3230', '3240', '3250', '3260', '3270', '3280', '3290', '3300',
#         '3310', '3320', '3330', '3340', '3350', '3360', '3370', '3380',
#         '3390', '3400', '3410'], dtype=object))

# %%
station['역번호'] = station['역번호'] * 10
station['역번호'] = station['역번호'].astype('str')

# %%
station['역번호'].unique(), subway['역번호'].unique()
# Out:
# (array(['1150', '1160', '1170', '1180', '1190', '1200', '1210', '1220',
#         '1230', '1240', '1250', '1260', '1270', '1280', '1290', '1300',
#         '1310', '1320', '1330', '1340', '1350', '1360', '1370', '1380',
#         '1390', '1400', '1410', '1420', '1430', '1440', '1450', '1460',
#         '2160', '2170', '2180', '2190', '2200', '2210', '2220', '2230',
#         '2240', '2250', '2260', '2270', '2280', '2290', '2300', '2310',
#         '2320', '2330', '2340', '2350', '2360', '2370', '2380', '2390',
#         '2400', '2410', '2420', '2430', '2440', '3120', '3130', '3140',
#         '3150', '3160', '3170', '3180', '3190', '3200', '3210', '3220',
#         '3230', '3240', '3250', '3260', '3270', '3280', '3290', '3300',
#         '3310', '3320', '3330', '3340', '3350', '3360', '3370', '3380',
#         '3390', '3400', '3410'], dtype=object),
#  array(['1150', '1160', '1170', '1180', '1190', '1200', '1210', '1220',
#         '1230', '1240', '1250', '1260', '1270', '1280', '1290', '1300',
#         '1310', '1320', '1330', '1340', '1350', '1360', '1370', '1380',
#         '1390', '1400', '1410', '1420', '1430', '1440', '1450', '1460',
#         '2160', '2170', '2180', '2190', '2200', '2210', '2220', '2230',
#         '2240', '2250', '2260', '2270', '2280', '2290', '2300', '2310',
#         '2320', '2330', '2340', '2350', '2360', '2370', '2380', '2390',
#         '2400', '2410', '2420', '2430', '2440', '3120', '3130', '3140',
#         '3150', '3160', '3170', '3180', '3190', '3200', '3210', '3220',
#         '3230', '3240', '3250', '3260', '3270', '3280', '3290', '3300',
#         '3310', '3320', '3330', '3340', '3350', '3360', '3370', '3380',
#         '3390', '3400', '3410'], dtype=object))

# %%
station = station[['역번호', '역위도', '역경도']]

# %%
subway_merge = pd.merge(subway, station, on='역번호', how='inner')

# %%
year = pd.DataFrame(subway_merge.groupby(by=['년도','역번호','역명'])['일계'].mean())

# %%
year = year.reset_index()

# %%
year_2017 = year[ year['년도'] == 2017]

# %%
year_2017 = pd.merge(year_2017, station, on='역번호', how='inner')

# %%
year_2017
# Out:
#       년도   역번호       역명            일계        역위도         역경도
# 0   2017  1150     설화명곡   4177.523288  35.798718  128.489318
# 1   2017  1160       화원   3532.083562  35.804357  128.500404
# 2   2017  1170       대곡   6914.000000  35.809497  128.510391
# 3   2017  1180       진천   7011.487671  35.813826  128.520397
# 4   2017  1190       월배   4454.669863  35.816276  128.528392
# 5   2017  1200       상인  13269.935616  35.818966  128.535684
# 6   2017  1210       월촌   5139.905479  35.823688  128.543277
# 7   2017  1220       송현   4081.258904  35.831079  128.549562
# 8   2017  1230      성당못  10433.934247  35.837471  128.555224
# 9   2017  1240       대명   4670.100000  35.839302  128.563288
# 10  2017  1250      안지랑   4776.526027  35.839243  128.571705
# 11  2017  1260      현충로   3926.819178  35.840911  128.579194
# 12  2017  1270     영대병원   6433.045205  35.844269  128.586057
# 13  2017  1280       교대   4379.009589  35.851106  128.588432
# 14  2017  1290      명덕1   4350.538356  35.858026  128.582436
# 15  2017  1300     반월당1  10835.495890  35.864678  128.591147
# 16  2017  1310      중앙로  20940.647945  35.870913  128.591799
# 17  2017  1320      대구역   9572.324658  35.876369  128.588486
# 18  2017  1330     칠성시장   5368.231507  35.876141  128.602971
# 19  2017  1340       신천   4888.936986  37.511624  127.083391
# 20  2017  1350     동대구역  18569.212329  35.877303  128.627513
# 21  2017  1360      동구청   4125.853425  35.883837  128.631623
# 22  2017  1370      아양교   5652.653425  35.887162  128.637566
# 23  2017  1380       동촌   2147.458904  35.886159  128.649053
# 24  2017  1390       해안   2934.628767  35.883898  128.659311
# 25  2017  1400       방촌   3367.421918  35.879692  128.669976
# 26  2017  1410       용계   2085.694521  35.876273  128.681415
# 27  2017  1420       율하   4830.436986  35.869579  128.693032
# 28  2017  1430       신기   4195.341096  35.866759  128.701658
# 29  2017  1440      반야월   2533.871233  35.865999  128.713553
# ..   ...   ...      ...           ...        ...         ...
# 61  2017  3120   칠곡경대병원   1333.886301  35.958394  128.559914
# 62  2017  3130       학정    343.815068  35.951577  128.559196
# 63  2017  3140       팔거   4426.127397  35.944126  128.558354
# 64  2017  3150       동천   1980.671233  35.937707  128.556660
# 65  2017  3160     칠곡운암   4041.712329  35.931487  128.554571
# 66  2017  3170       구암   2489.513699  35.925761  128.550408
# 67  2017  3180       태전   2204.812329  35.919708  128.547495
# 68  2017  3190       매천   2122.443836  35.912733  128.543379
# 69  2017  3200     매천시장    858.323288  35.904463  128.545761
# 70  2017  3210       팔달   1134.824658  35.897850  128.546757
# 71  2017  3220       공단   1234.079452  35.891985  128.553620
# 72  2017  3230       만평   2001.189041  35.889868  128.561021
# 73  2017  3240     팔달시장   2164.991781  35.888860  128.567844
# 74  2017  3250       원대   1747.372603  35.887867  128.574271
# 75  2017  3260      북구청   3376.320548  35.883893  128.581480
# 76  2017  3270     달성공원   1532.326027  35.875779  128.582090
# 77  2017  3280     서문시장   7955.845205  35.869750  128.582242
# 78  2017  3290      신남3   1689.686301  35.864271  128.582347
# 79  2017  3300       남산   3110.365753  35.856700  128.583358
# 80  2017  3310      명덕3   2967.757534  35.856975  128.590013
# 81  2017  3320     건들바위   1320.064384  35.855417  128.599626
# 82  2017  3330      대봉교   3240.139726  35.855005  128.606358
# 83  2017  3340     수성시장   2695.256164  35.854331  128.616034
# 84  2017  3350  수성구민운동장   2013.198630  35.852561  128.625084
# 85  2017  3360    어린이회관   1320.769863  35.845212  128.624469
# 86  2017  3370       황금   3110.817808  35.839110  128.623972
# 87  2017  3380      수성못   2555.309589  35.831362  128.623198
# 88  2017  3390       지산   2437.691781  35.825171  128.631909
# 89  2017  3400       범물   4107.767123  35.820844  128.640096
# 90  2017  3410       용지   2222.221918  35.818273  128.646517
#
# [91 rows x 6 columns]

# %%
lon = year_2017['역위도'].mean()
lat = year_2017['역경도'].mean()

# %%
pip install folium
# Out:
# Requirement already satisfied: folium in c:\users\user\anaconda3\lib\site-packages (0.10.0)
# Requirement already satisfied: requests in c:\users\user\anaconda3\lib\site-packages (from folium) (2.22.0)
# Requirement already satisfied: branca>=0.3.0 in c:\users\user\anaconda3\lib\site-packages (from folium) (0.3.1)
# Requirement already satisfied: jinja2>=2.9 in c:\users\user\anaconda3\lib\site-packages (from folium) (2.10.1)
# Requirement already satisfied: numpy in c:\users\user\anaconda3\lib\site-packages (from folium) (1.16.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\user\anaconda3\lib\site-packages (from requests->folium) (1.24.2)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\user\anaconda3\lib\site-packages (from requests->folium) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\user\anaconda3\lib\site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\lib\site-packages (from requests->folium) (2019.6.16)
# Requirement already satisfied: six in c:\users\user\anaconda3\lib\site-packages (from branca>=0.3.0->folium) (1.12.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\user\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (1.1.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import folium

# %%
daegu = folium.Map(location= [lon, lat], zoom_start=12)
daegu
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
for index in year_2017.index:
    lat = year_2017.loc[index, '역위도']
    lon = year_2017.loc[index, '역경도']
    
    folium.CircleMarker( [lat,lon],
                       radius = year_2017.loc[index, '일계']/ 1000,
                       popup = year_2017.loc[index, '역명'],
                       color='blue', fill= True).add_to(daegu)

# %%
daegu
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
