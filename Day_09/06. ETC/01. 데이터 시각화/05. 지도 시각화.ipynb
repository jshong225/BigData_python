# %% [markdown]
# ## 우리나라 지도그리는 모듈 배포 - 인구소멸위기지역, 여성인구비율 등등 (PinkWink)
# > https://pinkwink.kr/1133

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

import platform
from matplotlib import font_manager, rc
if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
    rc('font', family=font_name)

plt.rcParams['axes.unicode_minus'] = False

# %%
import drawKorea as dK

# %%
dK.draw_korea_pd.head(5)
# Out:
#     x  y      ID
# 0   7  0      철원
# 1   8  0      화천
# 2   9  0      양구
# 3  10  0  고성(강원)
# 4   3  1      양주

# %%
dK.simpleDraw(dK.draw_korea_pd)

# %%
korea_pop = pd.read_csv('../data/pop_exam.csv', index_col=0)
korea_pop.columns
# Out:
# Index(['광역시도', '시도', '20-39세여자', '20-39세합계', '65세이상합계', '인구수남자', '인구수여자',
#        '인구수합계', '소멸비율', '소멸위기지역', 'ID', 'x', 'y', '여성비', '2030여성비'],
#       dtype='object')

# %%
korea_pop.head(5)
# Out:
#   광역시도   시도  20-39세여자  20-39세합계  65세이상합계     인구수남자     인구수여자     인구수합계  \
# 0  강원도  강릉시   23098.0   49384.0  37679.0  106231.0  107615.0  213846.0
# 1  강원도  고성군    2529.0    7023.0   7151.0   15899.0   14215.0   30114.0
# 2  강원도  동해시    9753.0   21264.0  15124.0   47166.0   46131.0   93297.0
# 3  강원도  삼척시    7115.0   15823.0  14610.0   35253.0   34346.0   69599.0
# 4  강원도  속초시    8752.0   18708.0  12752.0   40288.0   41505.0   81793.0
#
#        소멸비율  소멸위기지역      ID   x  y       여성비    2030여성비
# 0  1.226041       0      강릉  11  3  0.323597  -3.227766
# 1  0.707314       1  고성(강원)  10  0 -2.796042 -13.989748
# 2  1.289738       0      동해  11  4 -0.554680  -4.133747
# 3  0.973990       1      삼척  11  5 -0.651590  -5.033812
# 4  1.372647       0      속초  10  1  0.743951  -3.217875

# %%
dK.drawKorea('소멸비율', korea_pop, 'RdBu')

# %%
dK.drawKorea('20-39세합계', korea_pop, 'Blues')

# %%
dK.drawKorea('65세이상합계', korea_pop, 'RdBu', zeroCenter=True)

# %%
dK.drawKorea('인구수남자', korea_pop, 'RdBu', zeroCenter=True)

# %%
dK.drawKorea('인구수여자', korea_pop, 'RdBu', zeroCenter=True)
