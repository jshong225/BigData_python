# %%
import urllib.request
url = 'http://www.naver.com'

# %%
data = urllib.request.urlopen(url).read()  # url의 주소에서 전달받은 값을 읽어 data 변수에 저장
data
# Out:
# b'<!doctype html>\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n<html lang="ko">\n<head>\n<meta charset="utf-8">\n<meta name="Referrer" content="origin">\n<meta http-equiv="Content-Script-Type" content="text/javascript">\n<meta http-equiv="Content-Style-Type" content="text/css">\n<meta http-equiv="X-UA-Compatible" content="IE=edge">\n<meta name="viewport" content="width=1100">\n<meta name="apple-mobile-web-app-title" content="NAVER" />\n<meta name="robots" content="index,nofollow"/>\n<meta name="description" content="\xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x84 \xeb\xa9\x94\xec\x9d\xb8\xec\x97\x90\xec\x84\x9c \xeb\x8b\xa4\xec\x96\x91\xed\x95\x9c \xec\xa0\x95\xeb\xb3\xb4\xec\x99\x80 \xec\x9c\xa0\xec\x9a\xa9\xed\x95\x9c \xec\xbb\xa8\xed\x85\x90\xec\xb8\xa0\xeb\xa5\xbc \xeb\xa7\x8c\xeb\x82\x98 \xeb\xb3\xb4\xec\x84\xb8\xec\x9a\x94"/>\n<meta property="og:title" content="\xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x84">\n<meta property="og:url" content="https://www.naver.com/">\n<meta property="og:image" content="https:/
# ...

# %%
text = data.decode("utf-8")
text
# Out:
# '<!doctype html>\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n<html lang="ko">\n<head>\n<meta charset="utf-8">\n<meta name="Referrer" content="origin">\n<meta http-equiv="Content-Script-Type" content="text/javascript">\n<meta http-equiv="Content-Style-Type" content="text/css">\n<meta http-equiv="X-UA-Compatible" content="IE=edge">\n<meta name="viewport" content="width=1100">\n<meta name="apple-mobile-web-app-title" content="NAVER" />\n<meta name="robots" content="index,nofollow"/>\n<meta name="description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/>\n<meta property="og:title" content="네이버">\n<meta property="og:url" content="https://www.naver.com/">\n<meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png">\n<meta property="og:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/>\n<meta name="twitter:card" content="summary">\n<meta name="twitter:title" content="">\n<meta name="twitter:url" content="https://www.naver.com/">\n<meta name
# ...

# %%
# url의 주소에서 전달받은 값을 kma.txt에 저장
urllib.request.urlretrieve(url, "naver.txt")
# Out:
# ('naver.txt', <http.client.HTTPMessage at 0x24fdce58908>)

# %%
import urllib.request
import urllib.parse

API = "http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp"

# 매개변수를 URL 인코딩   
values = {
    'stnId': '143'
}

params = urllib.parse.urlencode(values)
# 요청 전용 URL을 생성   
url = API + "?" + params
print(url)
# Out:
# http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp?stnId=143

# %%
# 다운로드   
data = urllib.request.urlopen(url).read()
data
# Out:
# b'<?xml version="1.0" encoding="utf-8" ?>\r\n<rss version="2.0">\r\n<channel>\r\n<title>\xea\xb8\xb0\xec\x83\x81\xec\xb2\xad \xec\x9c\xa1\xec\x83\x81 \xec\xa4\x91\xea\xb8\xb0\xec\x98\x88\xeb\xb3\xb4</title>\r\n<link>http://www.kma.go.kr/weather/forecast/mid-term_06.jsp</link>\r\n<description>\xea\xb8\xb0\xec\x83\x81\xec\xb2\xad \xeb\x82\xa0\xec\x94\xa8 \xec\x9b\xb9\xec\x84\x9c\xeb\xb9\x84\xec\x8a\xa4</description>\r\n<language>ko</language>\r\n<generator>\xea\xb8\xb0\xec\x83\x81\xec\xb2\xad</generator>\r\n<pubDate>2019\xeb\x85\x84 11\xec\x9b\x94 14\xec\x9d\xbc (\xeb\xaa\xa9)\xec\x9a\x94\xec\x9d\xbc 18:00</pubDate>\r\n <item>\r\n<author>\xea\xb8\xb0\xec\x83\x81\xec\xb2\xad</author>\r\n<category>\xec\x9c\xa1\xec\x83\x81\xec\xa4\x91\xea\xb8\xb0\xec\x98\x88\xeb\xb3\xb4</category>\r\n<title>\xea\xb2\xbd\xec\x83\x81\xeb\x82\xa8,\xeb\xb6\x81\xeb\x8f\x84 \xec\x9c\xa1\xec\x83\x81 \xec\xa4\x91\xea\xb8\xb0\xec\x98\x88\xeb\xb3\xb4 - 2019\xeb\x85\x84 11\xec\x9b\x94 14\xec\x9d\xbc (\xeb\xaa\xa9)\x
# ...

# %%
text = data.decode("utf-8")
print(text)
# Out:
# <?xml version="1.0" encoding="utf-8" ?>
# <rss version="2.0">
# <channel>
# <title>기상청 육상 중기예보</title>
# <link>http://www.kma.go.kr/weather/forecast/mid-term_06.jsp</link>
# <description>기상청 날씨 웹서비스</description>
# <language>ko</language>
# <generator>기상청</generator>
# <pubDate>2019년 11월 14일 (목)요일 18:00</pubDate>
#  <item>
# <author>기상청</author>
# <category>육상중기예보</category>
# <title>경상남,북도 육상 중기예보 - 2019년 11월 14일 (목)요일 18:00 발표</title>
# <link>http://www.kma.go.kr/weather/forecast/mid-term_06.jsp</link>
# <guid>http://www.kma.go.kr/weather/forecast/mid-term_06.jsp</guid>
# <description>
# 	<header>
# 		<title>경상남,북도 육상중기예보</title>
# 		<tm>201911141800</tm>
# ...

# %%
from bs4 import BeautifulSoup        # 크롤링 라이브러리
import urllib.request as req         # 웹에서 데이터 받아오는 라이브러리
from datetime import datetime as dt  # 현재 시간을 알려주는 라이브러리

# %%
# HTML 가져오기
url = "http://www.naver.com"
res = req.urlopen(url)

# HTML 분석하기
data = BeautifulSoup(res, "html.parser") # HTML 형식으로 데이터 변환

# 원하는 데이터 추출
rank = data.select(".ah_r")  # 실시간 검색어 순위
word = data.select(".ah_k")  # 실시간 검색어 

print(dt.now())
for r,w in zip(rank[:20],word[:20]):
    print(r.string, w.string)
# Out:
# 2019-11-15 01:05:00.762736
# 1 2022 카타르 월드컵 아시아 예선
# 2 수능 등급컷
# 3 베트남 축구
# 4 양승원
# 5 베트남 아랍에미리트
# 6 대한민국 레바논
# 7 이엘리야
# 8 박하선
# 9 한국 레바논
# 10 박하선 동생
# 11 레바논
# 12 베트남 uae
# 13 허정민
# 14 2019 수능 등급컷
# 15 축구
# 16 김선경
# 17 김희애 나이
# 18 해피투게더4
# 19 황인범
# 20 오늘 축구경기

# %%
url = "https://news.naver.com/main/read.nhn?mode=LS2D&mid=shm&sid1=101&sid2=259&oid=011&aid=0003614470"  # 뉴스 URL

# %%
res = req.urlopen(url)

# %%
res = req.urlopen(url)
data = BeautifulSoup(res, "html.parser")
newstitle = data.find("title").string  # 뉴스 타이틀 추출
newstext = data.find("div", class_='_article_body_contents').text.replace("\n","").replace("""// flash 오류를 우회하기 위한 함수 추가function _flash_removeCallback() {}""","")

# %%
newstitle = data.find("title").string 
newstitle
# Out:
# '신한은행, 무역공과 수출금융 업무 협약..신남방정책 기반 확대 : 네이버 뉴스'

# %%
# 불필요한 본문 내용 제거 (replace 함수 이용)
newstext = data.find("div", class_='_article_body_contents').text.replace("\n","").replace("""// flash 오류를 우회하기 위한 함수 추가function _flash_removeCallback() {}""","")

# %%
newstitle, newstext
# Out:
# ('신한은행, 무역공과 수출금융 업무 협약..신남방정책 기반 확대 : 네이버 뉴스',
# ...

# %%
# 네이버 금융을 통해 특정 회사의 주식 코드를 가지고 옴
# 해당 주식 코드는 시세 데이터이며 기준은 하루임
# 005930은 삼성전자의 주식 코드
# 1개의 페이지마다 10일의 데이터를 읽어옴
import pandas as pd     
stock_code = '005930'
page_num = 1
target_url = 'http://finance.naver.com/item/sise_day.nhn?code=' +\
        stock_code + '&page=' + str(page_num)

data = pd.read_html(target_url)

# %%
data
# Out:
# [            날짜       종가     전일비       시가       고가       저가         거래량
#  0          NaN      NaN     NaN      NaN      NaN      NaN         NaN
#  1   2019.11.14  52800.0   300.0  51900.0  52800.0  51900.0  11999523.0
#  2   2019.11.13  52500.0   100.0  52500.0  52500.0  52000.0   6225196.0
#  3   2019.11.12  52600.0  1000.0  51800.0  52600.0  51600.0   6576148.0
#  4   2019.11.11  51600.0   500.0  52200.0  52200.0  51400.0   8185952.0
#  5   2019.11.08  52100.0   800.0  53200.0  53300.0  52000.0  11603290.0
#  6          NaN      NaN     NaN      NaN      NaN      NaN         NaN
#  7          NaN      NaN     NaN      NaN      NaN      NaN         NaN
#  8          NaN      NaN     NaN      NaN      NaN      NaN         NaN
#  9   2019.11.07  52900.0   400.0  53400.0  53400.0  52400.0   9257116.0
#  10  2019.11.06  53300.0   600.0  52900.0  53500.0  52700.0  14361133.0
#  11  2019.11.05  52700.0   400.0  52400.0  52700.0  52100.0  10581034.0
# ...

# %%
data = data[0]

# %%
# 데이터 프레임에서 NaN 삭제
price_data = data.dropna(axis=0, how='any')

# %%
price_data
# Out:
#             날짜       종가     전일비       시가       고가       저가         거래량
# 1   2019.11.14  52800.0   300.0  51900.0  52800.0  51900.0  11999523.0
# 2   2019.11.13  52500.0   100.0  52500.0  52500.0  52000.0   6225196.0
# 3   2019.11.12  52600.0  1000.0  51800.0  52600.0  51600.0   6576148.0
# 4   2019.11.11  51600.0   500.0  52200.0  52200.0  51400.0   8185952.0
# 5   2019.11.08  52100.0   800.0  53200.0  53300.0  52000.0  11603290.0
# 9   2019.11.07  52900.0   400.0  53400.0  53400.0  52400.0   9257116.0
# 10  2019.11.06  53300.0   600.0  52900.0  53500.0  52700.0  14361133.0
# 11  2019.11.05  52700.0   400.0  52400.0  52700.0  52100.0  10581034.0
# 12  2019.11.04  52300.0  1100.0  51700.0  52300.0  51400.0  13012411.0
# 13  2019.11.01  51200.0   800.0  50600.0  51200.0  50400.0   8467846.0

# %%
price_data = price_data.reset_index(drop=True) # Index 초기화

# %%
price_data['날짜'] = pd.to_datetime(price_data['날짜'],
                                  format='%Y/%m/%d')
#  str 타입의 날짜 컬럼을 datetime 타입으로 변경

# %%
price_data.to_csv('삼성전자.csv', encoding='cp949')

# %%
from bs4 import BeautifulSoup  
import pandas as pd

# %%
from urllib.request import urlopen

url = "http://movie.naver.com/movie/sdb/rank/rmovie.nhn?sel=cur&date=20191115"

page = urlopen(url)

soup = BeautifulSoup(page, "html.parser")
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="http://imgmovie.naver.com/today/naverme/naverme_profile.jpg" property="me2:image">
# <meta content="네이버영화 " property="me2:post_tag">
# <meta content="네이버영화" property="me2:category1"/>
# <meta content="" property="me2:category2"/>
# <meta content="랭킹 : 네이버 영화" property="og:title"/>
# <meta content="영화, 영화인, 예매, 박스오피스 랭킹 정보 제공" property="og:description"/>
# <meta content="article" property="og:type"/>
# <meta content="https://movie.naver.com/movie/sdb/rank/rmovie.nhn?sel=cur&amp;date=20191115" property="og:url"/>
# <meta content="http://static.naver.net/m/movie/icons/OG_270_270.png" property="og:image"/><!-- http://static.naver.net/m/movie/im/navermovie.jpg -->
# <meta content="http://imgmovie.naver.com/today/naverme/naverme_profile.jpg" property="og:article:thumbnailUrl"/>
# ...

# %%
soup.find_all('div', 'tit5')
# Out:
# [<div class="tit5">
#  <a href="/movie/bi/mi/basic.nhn?code=179518" title="주전장">주전장</a>
#  </div>, <div class="tit5">
#  <a href="/movie/bi/mi/basic.nhn?code=10200" title="터미네이터 2:오리지널">터미네이터 2:오리지널</a>
#  </div>, <div class="tit5">
#  <a href="/movie/bi/mi/basic.nhn?code=25915" title="아이언 자이언트">아이언 자이언트</a>
#  </div>, <div class="tit5">
#  <a href="/movie/bi/mi/basic.nhn?code=183132" title="교회오빠">교회오빠</a>
#  </div>, <div class="tit5">
#  <a href="/movie/bi/mi/basic.nhn?code=10101" title="로마의 휴일">로마의 휴일</a>
#  </div>, <div class="tit5">
#  <a href="/movie/bi/mi/basic.nhn?code=177374" title="증인">증인</a>
#  </div>, <div class="tit5">
#  <a href="/movie/bi/mi/basic.nhn?code=189053" title="블랙머니">블랙머니</a>
#  </div>, <div class="tit5">
#  <a href="/movie/bi/mi/basic.nhn?code=66158" title="어거스트 러쉬">어거스트 러쉬</a>
#  </div>, <div class="tit5">
#  <a href="/movie/bi/mi/basic.nhn?code=130989" title="룸">룸</a>
#  </div>, <div class="tit5">
# ...

# %%
soup.find_all('div', 'tit5')[0]
# Out:
# <div class="tit5">
# <a href="/movie/bi/mi/basic.nhn?code=179518" title="주전장">주전장</a>
# </div>

# %%
soup.find_all('div', 'tit5')[0].a
# Out:
# <a href="/movie/bi/mi/basic.nhn?code=179518" title="주전장">주전장</a>

# %%
soup.find_all('div', 'tit5')[0].a.string
# Out:
# '주전장'

# %%
soup.find_all('td', 'point')
# Out:
# [<td class="point">9.49</td>,
#  <td class="point">9.43</td>,
#  <td class="point">9.33</td>,
#  <td class="point">9.27</td>,
#  <td class="point">9.23</td>,
#  <td class="point">9.08</td>,
#  <td class="point">9.07</td>,
#  <td class="point">9.00</td>,
#  <td class="point">8.95</td>,
#  <td class="point">8.91</td>,
#  <td class="point">8.77</td>,
#  <td class="point">8.76</td>,
#  <td class="point">8.76</td>,
#  <td class="point">8.67</td>,
#  <td class="point">8.66</td>,
#  <td class="point">8.66</td>,
#  <td class="point">8.57</td>,
#  <td class="point">8.55</td>,
#  <td class="point">8.49</td>,
#  <td class="point">8.48</td>,
#  <td class="point">8.40</td>,
#  <td class="point">8.32</td>,
#  <td class="point">8.29</td>,
#  <td class="point">8.29</td>,
#  <td class="point">8.26</td>,
#  <td class="point">8.12</td>,
#  <td class="point">8.09</td>,
#  <td class="point">8.08</td>,
#  <td class="point">7.90</td>,
#  <td class="point">7.87</td>,
#  <td class="point">7.81</td>,
# ...

# %%
len(soup.find_all('td', 'point'))
# Out:
# 46

# %%
soup.find_all('td', 'point')[0].string
# Out:
# '9.49'

# %%
movie_name = [soup.find_all('div', 'tit5')[n].a.string for n in range(0, len(soup.find_all('div', 'tit5')))]
movie_name
# Out:
# ['주전장',
#  '터미네이터 2:오리지널',
#  '아이언 자이언트',
#  '교회오빠',
#  '로마의 휴일',
#  '증인',
#  '블랙머니',
#  '어거스트 러쉬',
#  '룸',
#  '벌새',
#  '펄프 픽션',
#  '람보 : 라스트 워',
#  '너의 이름은.',
#  '김광석',
#  '조커',
#  '닥터 슬립',
#  '터미네이터: 다크 페이트',
#  '더 킹: 헨리 5세',
#  '장고:분노의 추적자',
#  '기생충',
#  '메기',
#  '영주',
#  '리스본행 야간열차',
#  '저수지의 개들',
#  '킬 빌 - 1부',
#  '신의 한 수: 귀수편',
#  '프란시스 하',
#  '죽거나 혹은 나쁘거나',
#  '가장 보통의 연애',
#  '퍼펙트맨',
#  '날씨의 아이',
#  '김군',
#  '원스 어폰 어 타임... 인 할리우드',
#  '말레피센트 2',
#  '극장판 헬로카봇 : 달나라를 구해줘!',
#  '위아영',
#  '47미터 2',
#  '제미니 맨',
#  '경주',
#  '쏘아올린 불꽃, 밑에서 볼까? 옆에서 볼까?',
#  '82년생 김지영',
#  '펭귄 하이웨이',
#  '나쁜 녀석들: 더 무비',
#  '다이빙벨',
#  '판소리 복서',
#  '유열의 음악앨범']

# %%
movie_point = [soup.find_all('td', 'point')[n].string for n in range(0, len(soup.find_all('div', 'tit5')))]
movie_point
# Out:
# ['9.49',
#  '9.43',
#  '9.33',
#  '9.27',
#  '9.23',
#  '9.08',
#  '9.07',
#  '9.00',
#  '8.95',
#  '8.91',
#  '8.77',
#  '8.76',
#  '8.76',
#  '8.67',
#  '8.66',
#  '8.66',
#  '8.57',
#  '8.55',
#  '8.49',
#  '8.48',
#  '8.40',
#  '8.32',
#  '8.29',
#  '8.29',
#  '8.26',
#  '8.12',
#  '8.09',
#  '8.08',
#  '7.90',
#  '7.87',
#  '7.81',
#  '7.78',
#  '7.63',
#  '7.61',
#  '7.49',
#  '7.36',
#  '7.03',
#  '6.81',
#  '6.78',
#  '6.75',
#  '6.67',
#  '6.62',
#  '6.44',
#  '6.38',
#  '6.19',
#  '6.08']

# %%
date = pd.date_range('20190101', periods=319, freq='D')
date
# Out:
# DatetimeIndex(['2019-01-01', '2019-01-02', '2019-01-03', '2019-01-04',
#                '2019-01-05', '2019-01-06', '2019-01-07', '2019-01-08',
#                '2019-01-09', '2019-01-10',
#                ...
#                '2019-11-06', '2019-11-07', '2019-11-08', '2019-11-09',
#                '2019-11-10', '2019-11-11', '2019-11-12', '2019-11-13',
#                '2019-11-14', '2019-11-15'],
#               dtype='datetime64[ns]', length=319, freq='D')

# %%
import urllib
from tqdm import tqdm_notebook

movie_date = []
movie_name = []
movie_point = []

for today in tqdm_notebook(date):
    html = "http://movie.naver.com/" + \
                                    "movie/sdb/rank/rmovie.nhn?sel=cur&date={date}"
    response = urlopen(html.format(date=
                                   urllib.parse.quote(today.strftime('%Y%m%d'))))
    soup = BeautifulSoup(response, "html.parser")
    
    end = len(soup.find_all('td', 'point'))
    
    movie_date.extend([today for n in range(0, end)])
    movie_name.extend([soup.find_all('div', 'tit5')[n].a.string for n in range(0, end)])
    movie_point.extend([soup.find_all('td', 'point')[n].string for n in range(0, end)])
# Out:
# c:\program files\python37\lib\site-packages\ipykernel_launcher.py:8: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# ...

# %%
len(movie_date), len(movie_name), len(movie_point)
# Out:
# (13795, 13795, 13795)

# %%
movie = pd.DataFrame({'date':movie_date, 
                      'name':movie_name, 
                      'point':movie_point})
movie.head()
# Out:
#         date                   name point
# 0 2019-01-01               보헤미안 랩소디  9.49
# 1 2019-01-01                  헌터 킬러  9.43
# 2 2019-01-01             폴란드로 간 아이들  9.42
# 3 2019-01-01                  트루먼 쇼  9.32
# 4 2019-01-01  점박이 한반도의 공룡2 : 새로운 낙원  9.24

# %%
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13795 entries, 0 to 13794
# Data columns (total 3 columns):
# date     13795 non-null datetime64[ns]
# name     13795 non-null object
# point    13795 non-null object
# dtypes: datetime64[ns](1), object(2)
# memory usage: 323.4+ KB

# %%
movie['point'] = movie['point'].astype(float)
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13795 entries, 0 to 13794
# Data columns (total 3 columns):
# date     13795 non-null datetime64[ns]
# name     13795 non-null object
# point    13795 non-null float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 323.4+ KB

# %%
import numpy as np

movie_unique = pd.pivot_table(movie, index=['name'], aggfunc=np.sum)
movie_best = movie_unique.sort_values(by='point', ascending=False)
movie_best.head()
# Out:
#           point
# name
# 교회오빠    1675.47
# 그린 북    1617.71
# 인생 후르츠  1562.02
# 기생충     1445.63
# 가버나움    1362.68

# %%
tmp = movie.query('name == ["기생충"]')
tmp
# Out:
#             date name  point
# 6608  2019-05-30  기생충   8.82
# 6652  2019-05-31  기생충   8.81
# 6696  2019-06-01  기생충   8.78
# 6739  2019-06-02  기생충   8.70
# 6782  2019-06-03  기생충   8.62
# ...          ...  ...    ...
# 13584 2019-11-11  기생충   8.48
# 13630 2019-11-12  기생충   8.48
# 13676 2019-11-13  기생충   8.48
# 13722 2019-11-14  기생충   8.48
# 13768 2019-11-15  기생충   8.48
#
# [170 rows x 3 columns]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(12,8))
plt.plot(tmp['date'], tmp['point'])
plt.legend(loc='best')
plt.grid()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
movie_best.head(10)
# Out:
#               point
# name
# 교회오빠        1675.47
# 그린 북        1617.71
# 인생 후르츠      1562.02
# 기생충         1445.63
# 가버나움        1362.68
# 알라딘         1357.58
# 일일시호일       1356.37
# 폴란드로 간 아이들  1209.00
# 어벤져스: 엔드게임  1183.95
# 극한직업        1123.11

# %%
movie_pivot = pd.pivot_table(movie, index=["date"], 
                             columns=['name'], values=['point'])
movie_pivot.head()
# Out:
#             point                                                              \
# name       0.0MHz 1919 유관순 28일 후 47미터 2 4월 이야기 500일의 썸머 7년-그들이 없는 언론 82년생 김지영
# date
# 2019-01-01    NaN      NaN   NaN    NaN    NaN      NaN         8.52      NaN
# 2019-01-02    NaN      NaN   NaN    NaN    NaN      NaN         8.52      NaN
# 2019-01-03    NaN      NaN   NaN    NaN    NaN      NaN          NaN      NaN
# 2019-01-04    NaN      NaN   NaN    NaN    NaN      NaN          NaN      NaN
# 2019-01-05    NaN      NaN   NaN    NaN    NaN      NaN          NaN      NaN
#
#                              ...                                             \
# name       B급 며느리 PMC: 더 벙커  ... 헬보이 현기증  혈투 호두까기 인형과 4개의 왕국 호랑이보다 무서운 겨울손님
# date                         ...
# 2019-01-01    NaN      5.57  ... NaN NaN NaN            7.39            NaN
# 2019-01-02    NaN      5.52  ... NaN NaN NaN            7.40            NaN
# 2019-01-03    NaN      5.50  ... NaN NaN NaN            7.40            NaN
# ...

# %%
movie_pivot.columns = movie_pivot.columns.droplevel()

# %%
movie_pivot.head()
# Out:
# name        0.0MHz  1919 유관순  28일 후  47미터 2  4월 이야기  500일의 썸머  7년-그들이 없는 언론  \
# date
# 2019-01-01     NaN       NaN    NaN     NaN     NaN       NaN          8.52
# 2019-01-02     NaN       NaN    NaN     NaN     NaN       NaN          8.52
# 2019-01-03     NaN       NaN    NaN     NaN     NaN       NaN           NaN
# 2019-01-04     NaN       NaN    NaN     NaN     NaN       NaN           NaN
# 2019-01-05     NaN       NaN    NaN     NaN     NaN       NaN           NaN
#
# name        82년생 김지영  B급 며느리  PMC: 더 벙커  ...  헬보이  현기증  혈투  호두까기 인형과 4개의 왕국  \
# date                                     ...
# 2019-01-01       NaN     NaN       5.57  ...  NaN  NaN NaN             7.39
# 2019-01-02       NaN     NaN       5.52  ...  NaN  NaN NaN             7.40
# 2019-01-03       NaN     NaN       5.50  ...  NaN  NaN NaN             7.40
# 2019-01-04       NaN     NaN       5.48  ...  NaN  NaN NaN             7.40
# 2019-01-05       NaN     NaN       5.42  ...  NaN  NaN NaN             7.40
#
# ...

# %%
import platform
from matplotlib import font_manager, rc

path = "c:/Windows/Fonts/malgun.ttf"
if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system... sorry~~~~')

# %%
target_col = ['기생충', '어벤져스: 엔드게임']
plt.figure(figsize=(12,6))
plt.plot(movie_pivot[target_col])
plt.legend(target_col, loc='best')
plt.grid()
plt.show()
